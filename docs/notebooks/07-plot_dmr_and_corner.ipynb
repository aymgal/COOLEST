# %% [markdown]
# # Quick DMR and Corner Plotting Function
#
# The following cells will make a DMR (data, model, residual) plot and a corner plot for your data. The function will also return some key information for your lensing system. Compress your COOLEST files into a .tar.gz file before using. An example COOLEST file is included (database/dmr_corner/coolest.tar.gz).
#
# If using a .tar.gz that does not contain a chains file, dmr_corner will not generate a corner plot.

# %%
from coolest.api import plot_util as plut

# %%
# plut.dmr_corner('database/dmr_corner/coolest.tar.gz', 'database/dmr_corner/outputs')
# Multi 1 has a single galaxy and two lens planes
# plut.dmr_corner('database/dmr_corner/multi1.zip', 'database/dmr_corner/outputs')
# Multi 2 has 2 sources where the nearer source is also a lens plane for the farther source, so we should see two rings
# plut.dmr_corner('database/dmr_corner/multi2.zip', 'database/dmr_corner/outputs')
# Multi 3 is the same as multi 2 except the nearer source is unlensed.
# plut.dmr_corner('database/dmr_corner/multi3.zip', 'database/dmr_corner/outputs')
# Multi 4: zip of the coolest_1 code from notebook 4
# plut.dmr_corner('database/dmr_corner/multi4.zip', 'database/dmr_corner/outputs')
# Multi 5: multi 4 with two sources
# plut.dmr_corner('database/dmr_corner/multi5.zip', 'database/dmr_corner/outputs')
# Multi 6: multi 4 with two mass planes
# plut.dmr_corner('database/dmr_corner/multi6.zip', 'database/dmr_corner/outputs')
# Multi 7: multi 6 with mass planes at same redshift but second mass profile scaled by beta
# plut.dmr_corner('database/dmr_corner/multi7.zip', 'database/dmr_corner/outputs')

plut.dmr_corner('database/dmr_corner/beta_corner_test.zip', 'database/dmr_corner/outputs')
# Out:
# C:\Users\aaang\OneDrive - Northeastern University\Schoolwork\CUNY\Research\COOLEST\coolest\template\json.py:530: UserWarning: Warning: the entity 'ExternalShear' is a mass field, hence it is likely a lensing mass component. Setting 'lensed' to False.
#   warnings.warn(f"Warning: the entity '{entity['name']}' is a mass field, hence it is likely a lensing mass component. Setting 'lensed' to False.")
# C:\Users\aaang\OneDrive - Northeastern University\Schoolwork\CUNY\Research\COOLEST\coolest\template\json.py:524: UserWarning: Warning: the galaxy 'PEMD' has a mass model, hence it is likely a lens galaxy. Setting 'lensed' to False.
#   warnings.warn(f"Warning: the galaxy '{entity['name']}' has a mass model, hence it is likely a lens galaxy. Setting 'lensed' to False.")
# ...

# %% [markdown]
# # Redshift test

# %%
# # plut.dmr_corner('database/dmr_corner/redshifttest/z1.0.zip', 'database/dmr_corner/outputs')
# plut.dmr_corner('database/dmr_corner/redshifttest/z1.2.zip', 'database/dmr_corner/outputs')
# plut.dmr_corner('database/dmr_corner/redshifttest/z1.4.zip', 'database/dmr_corner/outputs')
# plut.dmr_corner('database/dmr_corner/redshifttest/z1.6.zip', 'database/dmr_corner/outputs')
# # plut.dmr_corner('database/dmr_corner/redshifttest/z1.8.zip', 'database/dmr_corner/outputs')
# plut.dmr_corner('database/dmr_corner/redshifttest/z1.99.zip', 'database/dmr_corner/outputs')
# # plut.dmr_corner('database/dmr_corner/redshifttest/z2.0.zip', 'database/dmr_corner/outputs')

plut.dmr_corner('database/dmr_corner/redshifttest/z1.6.zip', 'database/dmr_corner/outputs')
# Out:
# C:\Users\aaang\OneDrive - Northeastern University\Schoolwork\CUNY\Research\COOLEST\coolest\template\json.py:497: UserWarning: Warning: the entity 'an external shear' is a mass field, hence it is likely a lensing mass component. Setting 'lensed' to False.
#   warnings.warn(f"Warning: the entity '{entity.name}' is a mass field, hence it is likely a lensing mass component. Setting 'lensed' to False.")
# C:\Users\aaang\OneDrive - Northeastern University\Schoolwork\CUNY\Research\COOLEST\coolest\template\json.py:491: UserWarning: Warning: the galaxy 'a lens galaxy' has a mass model, hence it is likely a lens galaxy. Setting 'lensed' to False.
#   warnings.warn(f"Warning: the galaxy '{entity.name}' has a mass model, hence it is likely a lens galaxy. Setting 'lensed' to False.")
# ...

# %%
# Redshift vs. Beta
